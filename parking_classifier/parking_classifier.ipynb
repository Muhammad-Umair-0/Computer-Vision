# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from skimage.io import imread
from skimage.transform import resize
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
import zipfile
import os

def unzip_file(source_zip, destination_dir):
    """
    Extracts a zip file from source_zip into destination_dir.
    """
    # Make sure destination folder exists
    os.makedirs(destination_dir, exist_ok=True)

    with zipfile.ZipFile(source_zip, 'r') as zip_ref:
        zip_ref.extractall(destination_dir)
        print(f"Unzipped {source_zip} to {destination_dir}")

# Example usage:
source_zip = "/content/drive/MyDrive/Learning /Computer Vision/clf-data.zip"       # zip file location
destination_dir = "/content/drive/MyDrive/Learning /Computer Vision"       # target directory

unzip_file(source_zip, destination_dir)
# Out:
# Unzipped /content/drive/MyDrive/Learning /Computer Vision/clf-data.zip to /content/drive/MyDrive/Learning /Computer Vision

# %%
input_dir ="/content/drive/MyDrive/Learning /Computer Vision/clf-data"
path = os.listdir(input_dir)
print(path)
categories = ['empty', 'not_empty']
len(path)
# Out:
# ['empty', 'not_empty']
# 2

# %% [markdown]
# # **Load and prepare data**

# %%
data = []
labels = []
for category_idx,category in enumerate(categories):
  for files in os.listdir(os.path.join(input_dir,category)):
    img_path  = os.path.join(input_dir,category,files)
    img = imread(img_path)
    img = resize(img,(15,15))
    data.append(img.flatten())
    labels.append(category_idx)

data = np.asarray(data)
labels = np.asarray(labels)

# %%
data[0]
# Out:
# array([0.42900875, 0.43685188, 0.39371463, 0.43046174, 0.43830488,
#        0.39516762, 0.42813374, 0.43597688, 0.39283962, 0.40350456,
#        0.4113477 , 0.36821044, 0.39385169, 0.40169483, 0.35855757,
#        0.38242654, 0.39026968, 0.34713243, 0.39250924, 0.40035238,
#        0.35721512, 0.40977988, 0.41762301, 0.37448576, 0.39099903,
#        0.39884217, 0.35570491, 0.35798007, 0.36585864, 0.32272138,
#        0.33404887, 0.34394855, 0.30081129, 0.33320643, 0.34185052,
#        0.2988957 , 0.3494432 , 0.35094855, 0.31096667, 0.35134589,
#        0.34754218, 0.30765243, 0.35623846, 0.35593084, 0.31597273,
#        0.36938808, 0.3769677 , 0.3339622 , 0.38852389, 0.39610351,
#        0.35309802, 0.38227321, 0.38985283, 0.34684733, 0.35478003,
#        0.36235965, 0.31935415, 0.34438075, 0.35196036, 0.30895487,
#        0.3364733 , 0.34405292, 0.30104742, 0.34896491, 0.35654453,
#        0.31353903, 0.37987571, 0.38745533, 0.34444984, 0.38779459,
#        0.39537421, 0.35236871, 0.36311526, 0.37069673, 0.32768883,
#        0.35146286, 0.35915027, 0.31604169, 0.360496  , 0.36778411,
#        0.32494076, 0.36605564, 0.36756269, 0.32761399, 0.37381087,
#        0.37360777, 0.33485714, 0.3526613 , 0.35185099, 0.32019637,
#        0.37210481, 0.37254356, 0.33310849, 0.38502525, 0.385464  ,
#        0.34602894, 0.38069803, 0.38113678, 0.34170172, 0.35769213,
#        0.35813088, 0.31869582, 0.3435561 , 0.34399485, 0.30455979,
#        0.33698692, 0.33742568, 0.29799061, 0.34123926, 0.34167801,
#        0.30224295, 0.36667793, 0.36711668, 0.32768162, 0.38027563,
#        0.38071438, 0.34127932, 0.35817418, 0.35861293, 0.31911036,
#        0.38506072, 0.38506072, 0.35368817, 0.39598873, 0.39598873,
#        0.36461618, 0.38477323, 0.38477323, 0.35340068, 0.36486979,
#        0.36486979, 0.33349725, 0.36393313, 0.36393313, 0.33256058,
#        0.36245001, 0.36245001, 0.33107746, 0.36241615, 0.36241615,
#        0.3310436 , 0.38321175, 0.38321175, 0.3518392 , 0.39072943,
#        0.39072943, 0.35935688, 0.36582987, 0.36582987, 0.33445732,
#        0.36739362, 0.36739362, 0.33602107, 0.35539404, 0.35539404,
#        0.32401342, 0.35222578, 0.3522255 , 0.31975125, 0.36851998,
#        0.36811677, 0.33558793, 0.34897882, 0.34574079, 0.32422177,
#        0.38563766, 0.38563766, 0.35426511, 0.39972339, 0.39972339,
#        0.36835084, 0.39588934, 0.39588934, 0.36451679, 0.36409261,
#        0.36409261, 0.33272006, 0.35145829, 0.35145829, 0.32008575,
#        0.35006219, 0.35006219, 0.31868964, 0.35059478, 0.35059478,
#        0.31922223, 0.38129   , 0.38129   , 0.34991745, 0.39171126,
#        0.39171126, 0.36033871, 0.36615489, 0.36615489, 0.33478235,
#        0.3594721 , 0.3594721 , 0.32809955, 0.34967245, 0.34967245,
#        0.3182999 , 0.34612118, 0.34612073, 0.31474943, 0.37866149,
#        0.37806776, 0.34847838, 0.38091213, 0.37726092, 0.35736601,
#        0.37151659, 0.37151659, 0.34014404, 0.39774593, 0.39774593,
#        0.36637338, 0.40294277, 0.40294277, 0.37157022, 0.37049387,
#        0.37049387, 0.33912132, 0.35403047, 0.35403047, 0.32265792,
#        0.3563605 , 0.3563605 , 0.32498795, 0.36466667, 0.36466667,
#        0.33329412, 0.38563159, 0.38563159, 0.35425904, 0.39823644,
#        0.39823644, 0.36686389, 0.37806119, 0.37806119, 0.34668864,
#        0.37649956, 0.37649956, 0.34512701, 0.39422245, 0.39422245,
#        0.3628499 , 0.41476151, 0.41476128, 0.38338943, 0.4719473 ,
#        0.47160827, 0.44125393, 0.50419255, 0.50109368, 0.47928869])

# %% [markdown]
# # train test split

# %%
x_train,x_test,y_train,y_test = train_test_split(data,labels,test_size=0.2,shuffle=True, random_state=42)

# %% [markdown]
# # Train classifier

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
classifier = SVC()
classifier.fit(x_train,y_train)
perameters = [{'gamma':[0.01,0.001,0.0001],'C':[1,10,100,1000]}]
grid_search = GridSearchCV(classifier,param_grid=perameters,scoring='accuracy',cv=5)
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid=[{'C': [1, 10, 100, 1000],
#                           'gamma': [0.01, 0.001, 0.0001]}],
#              scoring='accuracy')

# %%
prediction = grid_search.predict(x_test)
accuracy_score(y_test,prediction)
# Out:
# 1.0

# %%
best_estimator = grid_search.best_estimator_
best_estimator
# Out:
# SVC(C=10, gamma=0.01)

# %%
prediction = best_estimator.predict(x_test)
accuracy_score(y_test,prediction)
# Out:
# 1.0

# %%
import pickle

# Define the path to save the model
model_path = '/content/drive/MyDrive/Learning /Computer Vision/best_Classifier.pkl'

# Save the model
with open(model_path, 'wb') as f:
    pickle.dump(best_estimator, f)

print(f"Model saved successfully to {model_path}")
# Out:
# Model saved successfully to /content/drive/MyDrive/Learning /Computer Vision/best_Classifier.pkl
